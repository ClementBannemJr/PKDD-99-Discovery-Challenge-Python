# %% [markdown]
# ![Python Logo](./img/python-logo-master-v3-TM-flattened_small.png)
#
# # Financial Programming - IÉSEG, Lille - MBD 2019-2020
# ## Group Project - Financial Data

# %%
first_name = 'Clement'
last_name = 'Bannem'

# %% [markdown]
# ### Data Exploration

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pandasql import sqldf 
pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# **Input data**

# %%
# Import banking data
# Note: This data was extracted on 1999

# Each record describes characteristics of a client
client = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/client.asc', sep=';')

# Each record describes static characteristics of an account
account = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/account.asc', sep=';')

# Each record describes a credit card issued to an account
card = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/card.asc', sep=';')

# Each record describes demographic characteristics of a district
district = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/district.asc', sep=';')

# Each record relates together a client with an account
# i.e. this relation describes the rights of clients to operate accounts
disp = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/disp.asc', sep=';')

# Each record describes characteristics of a payment order (debits only)
order = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/order.asc', sep=';')

# Each record describes one transaction on an account
trans = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/trans.asc', sep=';', low_memory=False)

# Each record describes a loan granted for a given account
loan = pd.read_csv('C:/Users/abannem/Documents/MSc In Big Data For Business/Courses/7. Financial Programming/Group Project/Group Project_Customer Loan/data_berka/loan.asc', sep=';')

# %% [markdown]
# ## Adding information to each record, replacing obscure values.

# %% [markdown]
# #### Client record

# %%
#Adding birthyear and Age to the client data base
client['birth_year'] = client['birth_number'].transform(lambda bn: int('19' + str(bn)[:2]))
client['age'] = 1999 - client['birth_year']

# %%
#Extracting gender from client[birth_number] and reformating it
# Function to extract birth month and gender
def to_month_gender(birth_number):
    
    # Extract the birth month and birth day from the birth_number column
    mon = str(birth_number)
    birth_month = int(mon[2:4])
    day = str(birth_number)
    birth_day = int(day[4:])
    
    # Extract the gender from the birth month
    if birth_month > 50:
        gender = "F"
        birth_month = birth_month - 50
    else:
        gender = 'M'
        
    return pd.Series({'birth_month':birth_month, 'birth_day':birth_day, 'gender':gender})

# Apply the function to client table
client[['birth_month', 'birth_day', 'gender']] = client['birth_number'].apply(to_month_gender)

# %%
client.head()
# Out:
#    client_id  birth_number  district_id  birth_year  age  birth_month  \
# 0          1        706213           18        1970   29           12
# 1          2        450204            1        1945   54            2
# 2          3        406009            1        1940   59           10
# 3          4        561201            5        1956   43           12
# 4          5        605703            5        1960   39            7
#
#    birth_day gender
# 0         13      F
# 1          4      M
# 2          9      F
# 3          1      M
# 4          3      F

# %% [markdown]
# #### Account record

# %%
account.head()
# Out:
#    account_id  district_id         frequency    date
# 0         576           55  POPLATEK MESICNE  930101
# 1        3818           74  POPLATEK MESICNE  930101
# 2         704           55  POPLATEK MESICNE  930101
# 3        2378           16  POPLATEK MESICNE  930101
# 4        2632           24  POPLATEK MESICNE  930102

# %%
def replfreq (freqcode):
    if "MESICNE" in freqcode:
        freq = "MONTHLY"
    elif "TYDNE" in freqcode:
        freq = "WEEKLY"
    elif "OBRATU" in freqcode:
        freq = "AFTER TRANSACTION"
    
    return freq

def repldate (datecode): #replace the YYMMDD column with 3 columns for Year (YYYY) Month and Day
    Year = "19" + str(datecode)[:2]
    Month = str(datecode)[2:4]
    Day = str(datecode)[4:6]
    
    return pd.Series({'Year':Year,'Month':Month,'Day':Day})

# %%
account['freq'] = account["frequency"].apply(replfreq)

# %%
account[['Year','Month','Day']] = account["date"].apply(repldate)

# %%
account.head()
# Out:
#    account_id  district_id         frequency    date     freq  Year Month Day
# 0         576           55  POPLATEK MESICNE  930101  MONTHLY  1993    01  01
# 1        3818           74  POPLATEK MESICNE  930101  MONTHLY  1993    01  01
# 2         704           55  POPLATEK MESICNE  930101  MONTHLY  1993    01  01
# 3        2378           16  POPLATEK MESICNE  930101  MONTHLY  1993    01  01
# 4        2632           24  POPLATEK MESICNE  930102  MONTHLY  1993    01  02

# %% [markdown]
# #### Order record

# %%
order.head()
# Out:
#    order_id  account_id bank_to  account_to  amount k_symbol
# 0     29401           1      YZ    87144583  2452.0     SIPO
# 1     29402           2      ST    89597016  3372.7     UVER
# 2     29403           2      QR    13943797  7266.0     SIPO
# 3     29404           3      WX    83084338  1135.0     SIPO
# 4     29405           3      CD    24485939   327.0

# %%
def krepl (k): #replace the k_symbol by a more comprehensive string (used in multiple records)
    k = str(k)
    if 'POJISTNE' in k:
        payment = "INSURRANCE"
    elif 'SIPO' in k:
        payment = "HOUSEHOLD"
    elif 'UVER' in k:
        payment = "LOAN"
    elif 'LEASING' in k:
        payment = "LEASING"
    elif 'SLUZBY' in k:
        payment = "STATEMENT"
    elif "UROK" in k:
        payment = "INTEREST CREDITED"
    elif 'SANKC. UROK' in k:
        payment = "SANCTION INTEREST (NEGATIVE BALANCE)"
    elif 'DUCHOD' in k :
        payment = "OLD AGE PENSION"
    else:
        payment = "UNKNOWN"
    
    return payment

# %%
order["Payment characterization"] = order["k_symbol"].apply(krepl)

# %%
order.head()
# Out:
#    order_id  account_id bank_to  account_to  amount k_symbol  \
# 0     29401           1      YZ    87144583  2452.0     SIPO
# 1     29402           2      ST    89597016  3372.7     UVER
# 2     29403           2      QR    13943797  7266.0     SIPO
# 3     29404           3      WX    83084338  1135.0     SIPO
# 4     29405           3      CD    24485939   327.0
#
#   Payment characterization
# 0                HOUSEHOLD
# 1                     LOAN
# 2                HOUSEHOLD
# 3                HOUSEHOLD
# 4                  UNKNOWN

# %% [markdown]
# #### Transaction record

# %%
print(trans.shape)
trans.head()
# Out:
# (1056320, 10)
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  PRIJEM     VKLAD   700.0    700.0      NaN
# 1    171812         576  930101  PRIJEM     VKLAD   900.0    900.0      NaN
# 2    207264         704  930101  PRIJEM     VKLAD  1000.0   1000.0      NaN
# 3   1117247        3818  930101  PRIJEM     VKLAD   600.0    600.0      NaN
# 4    579373        1972  930102  PRIJEM     VKLAD   400.0    400.0      NaN
#
#   bank  account
# 0  NaN      NaN
# 1  NaN      NaN
# 2  NaN      NaN
# 3  NaN      NaN
# 4  NaN      NaN

# %% [markdown]
# ##### This record is more than a million row long. Any operation on this record will take some time, please process it carrefully.

# %%
#trans[['Year','Month','Day']] = trans["date"].apply(repldate)

# %%
def typerepl(Type):
    if "PRIJEM" in Type:
        transaction = "+"
    else:
        transaction = "-"
    return transaction

def operepl(ope):
    ope = str(ope)
    if "VYBER KARTOU" in ope:
        mode = "Withdrawal in C.C."
    elif "VKLAD" in ope:
        mode = "Credit in cash"
    elif "PREVOD Z UCTU" in ope:
        mode = "Withdrawal from another bank"
    elif "VYBER" in ope:
        mode = "Withdrawal in cash"
    elif "PREVOD NA UCET" in ope:
        mode = "Credit to another bank"
    else:
        mode = "UNKNOWN"
    return mode

# %%
trans["Payment Characterization"] = trans["k_symbol"].apply(krepl)
trans["Transaction Type"] = trans["type"].apply(typerepl)
trans["Transaction Mode"] = trans["operation"].apply(operepl)

# %%
trans.head(20)
# Out:
#     trans_id  account_id    date    type      operation  amount  balance  \
# 0     695247        2378  930101  PRIJEM          VKLAD   700.0    700.0
# 1     171812         576  930101  PRIJEM          VKLAD   900.0    900.0
# 2     207264         704  930101  PRIJEM          VKLAD  1000.0   1000.0
# 3    1117247        3818  930101  PRIJEM          VKLAD   600.0    600.0
# 4     579373        1972  930102  PRIJEM          VKLAD   400.0    400.0
# 5     771035        2632  930102  PRIJEM          VKLAD  1100.0   1100.0
# 6     452728        1539  930103  PRIJEM          VKLAD   600.0    600.0
# 7     725751        2484  930103  PRIJEM          VKLAD  1100.0   1100.0
# 8     497211        1695  930103  PRIJEM          VKLAD   200.0    200.0
# 9     232960         793  930103  PRIJEM          VKLAD   800.0    800.0
# 10    505240        1726  930103  PRIJEM          VKLAD  1000.0   1000.0
# 11    144541         485  930104  PRIJEM          VKLAD   300.0    300.0
# 12    637741        2177  930104  PRIJEM          VKLAD   800.0    800.0
# 13    689827        2357  930104  PRIJEM          VKLAD   800.0    800.0
# 14    846006        2881  930104  PRIJEM          VKLAD   700.0    700.0
# 15    637742        2177  930105  PRIJEM  PREVOD Z UCTU  5123.0   5923.0
# 16   2908688        9635  930105  PRIJEM          VKLAD   400.0    400.0
# 17    232961         793  930105  PRIJEM  PREVOD Z UCTU  3401.0   4201.0
# 18    192096         652  930105  PRIJEM          VKLAD   700.0    700.0
# 19    542215        1844  930106  PRIJEM          VKLAD   500.0    500.0
#
#    k_symbol bank     account Payment Characterization Transaction Type  \
# 0       NaN  NaN         NaN                  UNKNOWN                +
# 1       NaN  NaN         NaN                  UNKNOWN                +
# 2       NaN  NaN         NaN                  UNKNOWN                +
# 3       NaN  NaN         NaN                  UNKNOWN                +
# 4       NaN  NaN         NaN                  UNKNOWN                +
# 5       NaN  NaN         NaN                  UNKNOWN                +
# 6       NaN  NaN         NaN                  UNKNOWN                +
# 7       NaN  NaN         NaN                  UNKNOWN                +
# 8       NaN  NaN         NaN                  UNKNOWN                +
# 9       NaN  NaN         NaN                  UNKNOWN                +
# 10      NaN  NaN         NaN                  UNKNOWN                +
# 11      NaN  NaN         NaN                  UNKNOWN                +
# 12      NaN  NaN         NaN                  UNKNOWN                +
# 13      NaN  NaN         NaN                  UNKNOWN                +
# 14      NaN  NaN         NaN                  UNKNOWN                +
# 15   DUCHOD   YZ  62457513.0          OLD AGE PENSION                +
# 16      NaN  NaN         NaN                  UNKNOWN                +
# 17      NaN   IJ   6149286.0                  UNKNOWN                +
# 18      NaN  NaN         NaN                  UNKNOWN                +
# 19      NaN  NaN         NaN                  UNKNOWN                +
#
#                 Transaction Mode
# 0                 Credit in cash
# 1                 Credit in cash
# 2                 Credit in cash
# 3                 Credit in cash
# 4                 Credit in cash
# 5                 Credit in cash
# 6                 Credit in cash
# 7                 Credit in cash
# 8                 Credit in cash
# 9                 Credit in cash
# 10                Credit in cash
# 11                Credit in cash
# 12                Credit in cash
# 13                Credit in cash
# 14                Credit in cash
# 15  Withdrawal from another bank
# 16                Credit in cash
# 17  Withdrawal from another bank
# 18                Credit in cash
# 19                Credit in cash

# %%
trans.operation.isnull().sum()
# Out:
# 183114

# %% [markdown]
# #### Loan record

# %%
loan.head()
# Out:
#    loan_id  account_id    date  amount  duration  payments status
# 0     5314        1787  930705   96396        12    8033.0      B
# 1     5316        1801  930711  165960        36    4610.0      A
# 2     6863        9188  930728  127080        60    2118.0      A
# 3     5325        1843  930803  105804        36    2939.0      A
# 4     7240       11013  930906  274740        60    4579.0      A

# %%
loan[['Year','Month','Day']] = loan['date'].apply(repldate)

# %%
loan.head()
# Out:
#    loan_id  account_id    date  amount  duration  payments status  Year Month  \
# 0     5314        1787  930705   96396        12    8033.0      B  1993    07
# 1     5316        1801  930711  165960        36    4610.0      A  1993    07
# 2     6863        9188  930728  127080        60    2118.0      A  1993    07
# 3     5325        1843  930803  105804        36    2939.0      A  1993    08
# 4     7240       11013  930906  274740        60    4579.0      A  1993    09
#
#   Day
# 0  05
# 1  11
# 2  28
# 3  03
# 4  06

# %% [markdown]
# #### Card record

# %%
card.head()
# Out:
#    card_id  disp_id     type           issued
# 0     1005     9285  classic  931107 00:00:00
# 1      104      588  classic  940119 00:00:00
# 2      747     4915  classic  940205 00:00:00
# 3       70      439  classic  940208 00:00:00
# 4      577     3687  classic  940215 00:00:00

# %%
card[["Year","Month","Day"]] = card["issued"].apply(repldate)

# %%
card.head()
# Out:
#    card_id  disp_id     type           issued  Year Month Day
# 0     1005     9285  classic  931107 00:00:00  1993    11  07
# 1      104      588  classic  940119 00:00:00  1994    01  19
# 2      747     4915  classic  940205 00:00:00  1994    02  05
# 3       70      439  classic  940208 00:00:00  1994    02  08
# 4      577     3687  classic  940215 00:00:00  1994    02  15

# %% [markdown]
# #### District record

# %%
district.head()
# Out:
#    A1           A2               A3       A4  A5  A6  A7  A8  A9    A10  \
# 0   1  Hl.m. Praha           Prague  1204953   0   0   0   1   1  100.0
# 1   2      Benesov  central Bohemia    88884  80  26   6   2   5   46.7
# 2   3       Beroun  central Bohemia    75232  55  26   4   1   5   41.7
# 3   4       Kladno  central Bohemia   149893  63  29   6   2   6   67.4
# 4   5        Kolin  central Bohemia    95616  65  30   4   1   6   51.4
#
#      A11   A12   A13  A14    A15    A16
# 0  12541  0.29  0.43  167  85677  99107
# 1   8507  1.67  1.85  132   2159   2674
# 2   8980  1.95  2.21  111   2824   2813
# 3   9753  4.64  5.05  109   5244   5892
# 4   9307  3.85  4.43  118   2616   3040

# %%
district.columns = ['district_code', 'district_name', 'region', 'Number_inhabitants', 'A5', 'A6', 'A7', 'A8', 'A9', '%_urbans', 'Avrg_Salary',
       'A12', 'A13', 'A14', 'A15', 'A16']

# %% [markdown]
# ### Interactive Tool

# %% [markdown]
# Variable to create for credit scoring :

# %%
def loansituation(n):
    global paid,nbrpayment,lefttopay #
    
    #Subsetting the main table to have only transaction linked to loans
    IDinfoLoan = IDinfo[IDinfo["Payment Characterization"]=="LOAN"]
    
    #initiating in this order : number of transaction linked to loans, amount paid on the specific loan, nbr of payment,
    #amount left to pay for this specific loan
    testlen = len(IDinfoLoan)
    paid =0
    nbrpayment=0
    lefttopay = loantest.amount.iloc[n]
    
    for i in range(testlen):
        if loantest.payments.iloc[0]==round(IDinfoLoan["amount"].iloc[i]): #if this is true, it is a payment corresponding
            paid += round(IDinfoLoan["amount"].iloc[i])                    #to the specific loan we're looking at
            nbrpayment += 1
            lefttopay -= round(IDinfoLoan["amount"].iloc[i])
        else:
            None
    


def genID():
    global clientest, disptest, IDinfo, ID, districtest, transtest, loantest, cardtest #mainly for testing and debugging purpose
    
    #Prompting the user to enter an ID
    ID = int(input("Which client ID would you like to investigate ? \n Please type the ID here : "))
    clientest = client[client["client_id"]==ID]    
    disptest = disp[disp["client_id"]==ID]
    
    #Merging client and disp to get the account_id with client info
    IDinfo = pd.merge(clientest[["client_id","district_id","age","birth_month","gender"]],
                      disptest,
                      how="inner",
                      left_on="client_id",
                      right_on="client_id"
                     )
    
    #ordering the columns in a more comprehensive way
    IDinfo = IDinfo[["client_id","account_id","type","disp_id","age","birth_month","gender","district_id"]]
    
    #taking the district table based on client ID required
    districtest = district[district["district_code"]==IDinfo.district_id[0]] 
    
    #Adding district name and average Salary of this district to our main table
    IDinfo = pd.merge(IDinfo,    
                      districtest [["district_code","district_name","Avrg_Salary"]],
                      how="inner",
                      left_on="district_id",
                      right_on="district_code"
                     ) 
     
    #Taking transaction record of the client
    transtest = trans[trans["account_id"]==IDinfo["account_id"].iloc[0]]
    
    #Taking information about the potential credit card of the customer
    cardtest = card[card["disp_id"]==IDinfo["disp_id"].iloc[0]]
    
    #Adding those informations to our main table
    IDinfo = pd.merge(IDinfo,
                      transtest [["account_id","amount","balance","Year","Month","Day","Payment Characterization","Transaction Mode"]],
                      how="inner",
                      left_on="account_id",
                      right_on="account_id"
                     ) 
    
    #Taking information about the account of the client
    accountest = account[account["account_id"]==IDinfo["account_id"].iloc[0]]
    
    #last will be used to take the last row of the main table, to identify the last transaction registered
    last = len(IDinfo)-1
    
    #Loading the loan informations of the client
    loantest = loan[loan["account_id"]==IDinfo["account_id"].iloc[0]]
    
    #lenght of this table gives the number of loans taken
    nbofloan = len(loantest)
    
    
    ###PRINTING###
    
    #printing general information about the client
    print("-"*20)
    print("\nClient is a " + IDinfo.gender[0] + ", " + str(IDinfo.age[0]) + " years old and lives in " + 
          str(IDinfo.district_name[0]) + ".")
    print("\nHas been a client since " + accountest.Day.iloc[0]+"/"+
        str(accountest.Month.iloc[0])+"/"+str(accountest.Year.iloc[0]))
    if len(cardtest) == 0:
        print("\nThis client has no credit card in our bank.")
    else:
        for n in range(len(cardtest)):
            print("and was issued a " + str(cardtest.type.iloc[n]) + " credit card in " +
                  str(accountest.Day.iloc[n]) + "/" + str(accountest.Month.iloc[n]) + "/" + str(accountest.Year.iloc[n]) + ".")
    
    print("\nLast transaction registered occured the  " +
          str(IDinfo.Day[last])+"/"+str(IDinfo.Month[last])+"/"+str(IDinfo.Year[last]) + 
          ". \nBank account balance : " + str(IDinfo.balance[last])+".")
    
    #printing information about the last non-automatic transaction (no interest credit) to better identify
    #if the client is a sleeping account or not
    while IDinfo["Payment Characterization"][last]=="INTEREST CREDITED":
        last -=1
    
    print("\nLast transaction that was not automatic was " +str(IDinfo["Payment Characterization"][last])+ 
          "(" +str(IDinfo["Transaction Mode"][last]) + ")"" and occured in " +
          str(IDinfo.Day[last])+"/"+str(IDinfo.Month[last])+"/"+str(IDinfo.Year[last] ))
    
    
    #Printing information about the loans (their number, id, status, date of last payment if it has been fully payed,
    #amount left to pay, montly payment, time left before fully paid if everythin goes right.)
    if nbofloan == 0:
        print("\nThis client never took any loan from us.")
    
    else:
        print("\nThis client was issued " + str(nbofloan) + " loan(s). \nLoan status is/are :\n")
        
        for n in range(nbofloan):
            print("*Loan " +str(loantest["loan_id"].iloc[n]) + " issued the " + 
                  str(loantest.Day.iloc[n-1])+"/"+str(loantest.Month.iloc[n-1])+"/"+str(loantest.Year.iloc[n-1]) +
                  " for an amount of " + str(loantest.amount.iloc[n-1]) +
                  " and its status is " + str(loantest.status.iloc[n-1])+".")
            
            if loantest.status.iloc[n-1] =='A':
                loansituation(n)
                print("\n\tThe loan has been fully paid.")
            
            elif loantest.status.iloc[n] =='D':
                print("\n\tClient is late in the payment of the loan, the client is in debt !")
                loansituation(n)
                print("\n\tAmount already paid : " + str(paid) + 
                      "\n\tAmount left to pay : " + str(lefttopay) +
                      "\n\tNumber of payment made : " + str(nbrpayment))
                print("\n\t")
            
            elif loantest.status.iloc[n] =='B':
                print("\n\tThe contract is finished but the loan is not fully paid yet !")
                loansituation(n)
                print("\n\tAmount already paid : " + str(paid) + 
                      "\n\tAmount left to pay : " + str(lefttopay) +
                      "\n\tNumber of payment made : " + str(nbrpayment)) 
                
                IdinfoLoan = IDinfo[IDinfo["Payment Characterization"]=="LOAN"]
                loantest.payments[n]==IDinfoLoan[IDinfoLoan["amount"]]
                
            elif loantest.status.iloc[n] =='C':
                print("\n\tThe contract is still going and the loan is not fully paid yet. Situation is normal.")
                loansituation(n)
                print("\n\tAmount already paid : " + str(paid) + 
                      "\n\tAmount left to pay : " + str(lefttopay) +
                      "\n\tNumber of payment made : " + str(nbrpayment)) 
                
            else:
                print("\n\tThe status of this loan seems to been unknown or incorrectly specified in our files." +
                     "\n\tAsk IT for support on this problem.")
                
    print("\n" + "-"*20)
    #return IDinfo.tail()

# %%
# genID()

# %%
#To create a field to merge on 
card['account_id'] = card['disp_id']
card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 8 columns):
# card_id       892 non-null int64
# disp_id       892 non-null int64
# type          892 non-null object
# issued        892 non-null object
# Year          892 non-null object
# Month         892 non-null object
# Day           892 non-null object
# account_id    892 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 55.8+ KB

# %%
#To merge card and trans: created to see which card carried out which transaction.
card_transaction = pd.merge(card, trans, how = 'left', on = 'account_id')
card_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141244 entries, 0 to 141243
# Data columns (total 20 columns):
# card_id                     141244 non-null int64
# disp_id                     141244 non-null int64
# type_x                      141244 non-null object
# issued                      141244 non-null object
# Year                        141244 non-null object
# Month                       141244 non-null object
# Day                         141244 non-null object
# account_id                  141244 non-null int64
# trans_id                    140967 non-null float64
# date                        140967 non-null float64
# type_y                      140967 non-null object
# operation                   116526 non-null object
# amount                      140967 non-null float64
# balance                     140967 non-null float64
# k_symbol                    78140 non-null object
# bank                        37673 non-null object
# account                     39819 non-null float64
# Payment Characterization    140967 non-null object
# Transaction Type            140967 non-null object
# Transaction Mode            140967 non-null object
# dtypes: float64(5), int64(3), object(12)
# memory usage: 22.6+ MB

# %%
#To change name
client["district_code"] = client["district_id"]
client.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5369 entries, 0 to 5368
# Data columns (total 9 columns):
# client_id        5369 non-null int64
# birth_number     5369 non-null int64
# district_id      5369 non-null int64
# birth_year       5369 non-null int64
# age              5369 non-null int64
# birth_month      5369 non-null int64
# birth_day        5369 non-null int64
# gender           5369 non-null object
# district_code    5369 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 377.6+ KB

# %%
#start of basetable1
client_district = pd.merge(client, district, on = 'district_code', how = 'left')
#To set index
client_district.set_index('district_id')
client_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5369 entries, 0 to 5368
# Data columns (total 24 columns):
# client_id             5369 non-null int64
# birth_number          5369 non-null int64
# district_id           5369 non-null int64
# birth_year            5369 non-null int64
# age                   5369 non-null int64
# birth_month           5369 non-null int64
# birth_day             5369 non-null int64
# gender                5369 non-null object
# district_code         5369 non-null int64
# district_name         5369 non-null object
# region                5369 non-null object
# Number_inhabitants    5369 non-null int64
# A5                    5369 non-null int64
# A6                    5369 non-null int64
# A7                    5369 non-null int64
# A8                    5369 non-null int64
# A9                    5369 non-null int64
# %_urbans              5369 non-null float64
# Avrg_Salary           5369 non-null int64
# A12                   5369 non-null object
# A13                   5369 non-null float64
# A14                   5369 non-null int64
# A15                   5369 non-null object
# A16                   5369 non-null int64
# dtypes: float64(2), int64(17), object(5)
# memory usage: 1.0+ MB

# %%
#drop added filed for merge
client_district = client_district.drop(['district_code'], axis = 1)
#drop unwanted columns
client_district = client_district.drop(columns = ['A5','A6','A7','A8','A9','A12','A13','A14','A15','A16'])

client_district.head()
# Out:
#    client_id  birth_number  district_id  birth_year  age  birth_month  \
# 0          1        706213           18        1970   29           12
# 1          2        450204            1        1945   54            2
# 2          3        406009            1        1940   59           10
# 3          4        561201            5        1956   43           12
# 4          5        605703            5        1960   39            7
#
#    birth_day gender district_name           region  Number_inhabitants  \
# 0         13      F         Pisek    south Bohemia               70699
# 1          4      M   Hl.m. Praha           Prague             1204953
# 2          9      F   Hl.m. Praha           Prague             1204953
# 3          1      M         Kolin  central Bohemia               95616
# 4          3      F         Kolin  central Bohemia               95616
#
#    %_urbans  Avrg_Salary
# 0      65.3         8968
# 1     100.0        12541
# 2     100.0        12541
# 3      51.4         9307
# 4      51.4         9307

# %%
# Use so that each observation is a client 
client_district.set_index('client_id')
# Out:
#            birth_number  district_id  birth_year  age  birth_month  birth_day  \
# client_id
# 1                706213           18        1970   29           12         13
# 2                450204            1        1945   54            2          4
# 3                406009            1        1940   59           10          9
# 4                561201            5        1956   43           12          1
# 5                605703            5        1960   39            7          3
# 6                190922           12        1919   80            9         22
# 7                290125           15        1929   70            1         25
# 8                385221           51        1938   61            2         21
# 9                351016           60        1935   64           10         16
# 10               430501           57        1943   56            5          1
# 11               505822           57        1950   49            8         22
# 12               810220           40        1981   18            2         20
# 13               745529           54        1974   25            5         29
# 14               425622           76        1942   57            6         22
# 15               185828           21        1918   81            8         28
# 16               190225           21        1919   80            2         25
# 17               341013           76        1934   65           10         13
# 18               315405           76        1931   68            4          5
# 19               421228           47        1942   57           12         28
# 20               790104           46        1979   20            1          4
# 21               526029           12        1952   47           10         29
# 22               696011            1        1969   30           10         11
# 23               730529            1        1973   26            5         29
# 24               395729           43        1939   60            7         29
# 25               395423           21        1939   60            4         23
# 26               695420           74        1969   30            4         20
# 27               665326           54        1966   33            3         26
# 28               450929            1        1945   54            9         29
# 29               515911           30        1951   48            9         11
# 30               576009           74        1957   42           10          9
# ...                 ...          ...         ...  ...          ...        ...
# 13588            740129           46        1974   25            1         29
# 13590            770803           59        1977   22            8          3
# 13603            410728           46        1941   58            7         28
# 13608            635515           37        1963   36            5         15
# 13620            700726           16        1970   29            7         26
# 13640            555609           28        1955   44            6          9
# 13657            635512           59        1963   36            5         12
# 13658            570423           59        1957   42            4         23
# 13673            710220           39        1971   28            2         20
# 13687            590523           75        1959   40            5         23
# 13690            630516           70        1963   36            5         16
# 13694            765120            1        1976   23            1         20
# 13750            806113           12        1980   19           11         13
# 13751            790720           12        1979   20            7         20
# 13803            471114            1        1947   52           11         14
# 13820            485731           33        1948   51            7         31
# 13845            730216           15        1973   26            2         16
# 13852            720126            5        1972   27            1         26
# 13886            545412           44        1954   45            4         12
# 13912            751120           50        1975   24           11         20
# 13915            741123           77        1974   25           11         23
# 13921            706220           62        1970   29           12         20
# 13923            795222            7        1979   20            2         22
# 13924            525909           54        1952   47            9          9
# 13931            420101            8        1942   57            1          1
# 13955            456030            1        1945   54           10         30
# 13956            430406            1        1943   56            4          6
# 13968            680413           61        1968   31            4         13
# 13971            626019           67        1962   37           10         19
# 13998            535812           74        1953   46            8         12
#
#           gender      district_name           region  Number_inhabitants  \
# client_id
# 1              F              Pisek    south Bohemia               70699
# 2              M        Hl.m. Praha           Prague             1204953
# 3              F        Hl.m. Praha           Prague             1204953
# 4              M              Kolin  central Bohemia               95616
# 5              F              Kolin  central Bohemia               95616
# 6              M            Pribram  central Bohemia              107870
# 7              M      Cesky Krumlov    south Bohemia               58796
# 8              F            Trutnov     east Bohemia              121947
# 9              M          Prostejov    south Moravia              110643
# 10             M            Hodonin    south Moravia              161954
# 11             F            Hodonin    south Moravia              161954
# 12             M            Teplice    north Bohemia              128118
# 13             F       Brno - mesto    south Moravia              387570
# 14             F            Sumperk    north Moravia              127369
# 15             F              Tabor    south Bohemia              103347
# 16             M              Tabor    south Bohemia              103347
# 17             M            Sumperk    north Moravia              127369
# 18             F            Sumperk    north Moravia              127369
# 19             M          Pardubice     east Bohemia              162580
# 20             M             Nachod     east Bohemia              112709
# 21             F            Pribram  central Bohemia              107870
# 22             F        Hl.m. Praha           Prague             1204953
# 23             M        Hl.m. Praha           Prague             1204953
# 24             F     Hradec Kralove     east Bohemia              161854
# 25             F              Tabor    south Bohemia              103347
# 26             F    Ostrava - mesto    north Moravia              323870
# 27             F       Brno - mesto    south Moravia              387570
# 28             M        Hl.m. Praha           Prague             1204953
# 29             F            Sokolov     west Bohemia               94812
# 30             F    Ostrava - mesto    north Moravia              323870
# ...          ...                ...              ...                 ...
# 13588          M             Nachod     east Bohemia              112709
# 13590          M           Kromeriz    south Moravia              108871
# 13603          M             Nachod     east Bohemia              112709
# 13608          F         Litomerice    north Bohemia              114006
# 13620          M  Jindrichuv Hradec    south Bohemia               93931
# 13640          F      Plzen - sever     west Bohemia               72541
# 13657          F           Kromeriz    south Moravia              108871
# 13658          M           Kromeriz    south Moravia              108871
# 13673          M               Most    north Bohemia              119895
# 13687          M             Prerov    north Moravia              138032
# 13690          M            Karvina    north Moravia              285387
# 13694          F        Hl.m. Praha           Prague             1204953
# 13750          F            Pribram  central Bohemia              107870
# 13751          M            Pribram  central Bohemia              107870
# 13803          M        Hl.m. Praha           Prague             1204953
# 13820          F              Decin    north Bohemia              133777
# 13845          M      Cesky Krumlov    south Bohemia               58796
# 13852          M              Kolin  central Bohemia               95616
# 13886          F            Chrudim     east Bohemia              105606
# 13912          M            Svitavy     east Bohemia              102609
# 13915          M             Vsetin    north Moravia              148545
# 13921          F   Uherske Hradiste    south Moravia              145688
# 13923          F             Melnik  central Bohemia               94725
# 13924          F       Brno - mesto    south Moravia              387570
# 13931          M     Mlada Boleslav  central Bohemia              112065
# 13955          F        Hl.m. Praha           Prague             1204953
# 13956          M        Hl.m. Praha           Prague             1204953
# 13968          M             Trebic    south Moravia              117897
# 13971          F            Bruntal    north Moravia              106054
# 13998          F    Ostrava - mesto    north Moravia              323870
#
#            %_urbans  Avrg_Salary
# client_id
# 1              65.3         8968
# 2             100.0        12541
# 3             100.0        12541
# 4              51.4         9307
# 5              51.4         9307
# 6              58.0         8754
# 7              51.9         9045
# 8              70.5         8541
# 9              51.9         8441
# 10             48.0         8720
# 11             48.0         8720
# 12             85.3         9317
# 13            100.0         9897
# 14             51.2         8369
# 15             67.0         9104
# 16             67.0         9104
# 17             51.2         8369
# 18             51.2         8369
# 19             72.8         9538
# 20             73.5         8369
# 21             58.0         8754
# 22            100.0        12541
# 23            100.0        12541
# 24             76.3         9425
# 25             67.0         9104
# 26            100.0        10673
# 27            100.0         9897
# 28            100.0        12541
# 29             81.8         9650
# 30            100.0        10673
# ...             ...          ...
# 13588          73.5         8369
# 13590          62.1         8444
# 13603          73.5         8369
# 13608          62.3         9065
# 13620          56.9         8427
# 13640          36.9         8594
# 13657          62.1         8444
# 13658          62.1         8444
# 13673          89.9        10446
# 13687          64.6         8819
# 13690          89.9        10177
# 13694         100.0        12541
# 13750          58.0         8754
# 13751          58.0         8754
# 13803         100.0        12541
# 13820          84.7         8705
# 13845          51.9         9045
# 13852          51.4         9307
# 13886          53.0         8254
# 13912          52.0         8187
# 13915          53.5         8909
# 13921          40.7         8544
# 13923          63.4         9920
# 13924         100.0         9897
# 13931          69.4        11277
# 13955         100.0        12541
# 13956         100.0        12541
# 13968          53.8         8814
# 13971          63.1         8110
# 13998         100.0        10673
#
# [5369 rows x 12 columns]

# %%
#change name
basetable1 = client_district

# %%
#check for nulls
basetable1.isna().sum().sum()
# Out:
# 0

# %%
#to drop
#basetable1 = basetable1.drop(columns = ['birth_number'])
#set index on new table
basetable1.set_index('client_id')
basetable1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5369 entries, 0 to 5368
# Data columns (total 13 columns):
# client_id             5369 non-null int64
# birth_number          5369 non-null int64
# district_id           5369 non-null int64
# birth_year            5369 non-null int64
# age                   5369 non-null int64
# birth_month           5369 non-null int64
# birth_day             5369 non-null int64
# gender                5369 non-null object
# district_name         5369 non-null object
# region                5369 non-null object
# Number_inhabitants    5369 non-null int64
# %_urbans              5369 non-null float64
# Avrg_Salary           5369 non-null int64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 587.2+ KB

# %%
#transferred_out_amounts = order.groupby('account_id')["amount"].agg("sum")
#order["transferred_out_amounts"] = order["account_id"].map(transferred_out_amounts)
#order

# %%
def disponent (i):
        if i == "DISPONENT":
            return "Y"
        else:
            return "N"

# %%
Table1 = pd.merge(basetable1,disp, how = 'left', on = 'client_id')

Table2 = pd.merge(Table1,account, how = 'left', on = 'account_id')

Table3 = pd.merge(Table2,loan, how = 'left', on = 'account_id')

#Table4 = pd.merge(Table3,order, how ='left', on = 'account_id')

# %%
Table3["Disponent"] = Table3["type"].apply(disponent)
Table3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5369 entries, 0 to 5368
# Data columns (total 33 columns):
# client_id             5369 non-null int64
# birth_number          5369 non-null int64
# district_id_x         5369 non-null int64
# birth_year            5369 non-null int64
# age                   5369 non-null int64
# birth_month           5369 non-null int64
# birth_day             5369 non-null int64
# gender                5369 non-null object
# district_name         5369 non-null object
# region                5369 non-null object
# Number_inhabitants    5369 non-null int64
# %_urbans              5369 non-null float64
# Avrg_Salary           5369 non-null int64
# disp_id               5369 non-null int64
# account_id            5369 non-null int64
# type                  5369 non-null object
# district_id_y         5369 non-null int64
# frequency             5369 non-null object
# date_x                5369 non-null int64
# freq                  5369 non-null object
# Year_x                5369 non-null object
# Month_x               5369 non-null object
# Day_x                 5369 non-null object
# loan_id               827 non-null float64
# date_y                827 non-null float64
# amount                827 non-null float64
# duration              827 non-null float64
# payments              827 non-null float64
# status                827 non-null object
# Year_y                827 non-null object
# Month_y               827 non-null object
# Day_y                 827 non-null object
# Disponent             5369 non-null object
# dtypes: float64(6), int64(13), object(14)
# memory usage: 1.4+ MB

# %%
card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 8 columns):
# card_id       892 non-null int64
# disp_id       892 non-null int64
# type          892 non-null object
# issued        892 non-null object
# Year          892 non-null object
# Month         892 non-null object
# Day           892 non-null object
# account_id    892 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 55.8+ KB

# %%
trans.head()
# Out:
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  PRIJEM     VKLAD   700.0    700.0      NaN
# 1    171812         576  930101  PRIJEM     VKLAD   900.0    900.0      NaN
# 2    207264         704  930101  PRIJEM     VKLAD  1000.0   1000.0      NaN
# 3   1117247        3818  930101  PRIJEM     VKLAD   600.0    600.0      NaN
# 4    579373        1972  930102  PRIJEM     VKLAD   400.0    400.0      NaN
#
#   bank  account Payment Characterization Transaction Type Transaction Mode
# 0  NaN      NaN                  UNKNOWN                +   Credit in cash
# 1  NaN      NaN                  UNKNOWN                +   Credit in cash
# 2  NaN      NaN                  UNKNOWN                +   Credit in cash
# 3  NaN      NaN                  UNKNOWN                +   Credit in cash
# 4  NaN      NaN                  UNKNOWN                +   Credit in cash

# %%
Table3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5369 entries, 0 to 5368
# Data columns (total 33 columns):
# client_id             5369 non-null int64
# birth_number          5369 non-null int64
# district_id_x         5369 non-null int64
# birth_year            5369 non-null int64
# age                   5369 non-null int64
# birth_month           5369 non-null int64
# birth_day             5369 non-null int64
# gender                5369 non-null object
# district_name         5369 non-null object
# region                5369 non-null object
# Number_inhabitants    5369 non-null int64
# %_urbans              5369 non-null float64
# Avrg_Salary           5369 non-null int64
# disp_id               5369 non-null int64
# account_id            5369 non-null int64
# type                  5369 non-null object
# district_id_y         5369 non-null int64
# frequency             5369 non-null object
# date_x                5369 non-null int64
# freq                  5369 non-null object
# Year_x                5369 non-null object
# Month_x               5369 non-null object
# Day_x                 5369 non-null object
# loan_id               827 non-null float64
# date_y                827 non-null float64
# amount                827 non-null float64
# duration              827 non-null float64
# payments              827 non-null float64
# status                827 non-null object
# Year_y                827 non-null object
# Month_y               827 non-null object
# Day_y                 827 non-null object
# Disponent             5369 non-null object
# dtypes: float64(6), int64(13), object(14)
# memory usage: 1.4+ MB

# %%
order.head()
# Out:
#    order_id  account_id bank_to  account_to  amount k_symbol  \
# 0     29401           1      YZ    87144583  2452.0     SIPO
# 1     29402           2      ST    89597016  3372.7     UVER
# 2     29403           2      QR    13943797  7266.0     SIPO
# 3     29404           3      WX    83084338  1135.0     SIPO
# 4     29405           3      CD    24485939   327.0
#
#   Payment characterization
# 0                HOUSEHOLD
# 1                     LOAN
# 2                HOUSEHOLD
# 3                HOUSEHOLD
# 4                  UNKNOWN

# %%
order['bank_to'].nunique()
# Out:
# 13

# %%
orders_copy = order

# %%
order_a = pysqldf("""
SELECT account_id,
sum(amount) as order_amount, 
count(amount) as number_of_orders
FROM orders_copy
GROUP BY account_id
""")

# %%
order_a.head()
# Out:
#    account_id  order_amount  number_of_orders
# 0           1        2452.0                 1
# 1           2       10638.7                 2
# 2           3        5001.0                 3
# 3           4        3363.0                 2
# 4           5        2668.0                 1

# %%
trans_a = trans

# %%
trans_a =  pysqldf("""
SELECT account_id, operation,
sum(amount) as amount,
count(amount) as number_of_transaction,
Max(amount) as Max_transaction,
Min(amount) as Min_transaction,
avg(amount) as AVG_transaction,
            CASE 
                WHEN operation = 'VYBER KARTOU' THEN 'Credit Card Withdrawl'
                WHEN operation = 'VKLAD' THEN ' Credit in cash '
                WHEN operation = 'PREVOD Z UCTU' THEN 'Collection from another bank'
                WHEN operation = 'VYBER' THEN 'Withdrawl in cash'
                WHEN operation = 'PREVOD NA UCET' THEN 'Remittance to another banl'
                ELSE 'Other transaction'
            END AS TransactionMode,
            CASE 
                WHEN k_symbol = 'POJISTNE' THEN 'Insurance Payment'
                WHEN k_symbol = 'SLUZBY' THEN 'Payment for statement'
                WHEN k_symbol = 'UROK' THEN 'Intrest credited'
                WHEN k_symbol = 'SANKC. UROK' THEN 'Sanction interest if negative balance'
                WHEN k_symbol = 'SIPO' THEN 'Stands for household'
                WHEN k_symbol = 'DUCHOD' THEN 'Stands for old-age pension'
                WHEN k_symbol = '"UVER' THEN 'Stands for loan payment'
                ELSE 'Other'
            END AS TransactionCharacterization,
            SUM(CASE 
                    WHEN type = "PRIJEM" THEN 1 ELSE 0 END) as 'UsedForCredit',
            SUM(CASE 
                    WHEN type = "VYDAJ" THEN 1 ELSE 0 END) as 'Withdrawl'
FROM trans_a
GROUP BY account_id

""")

# %%
trans_a.head()
# Out:
#    account_id operation     amount  number_of_transaction  Max_transaction  \
# 0           1     VYBER   375174.5                    239          12600.0
# 1           2      None  3151479.3                    478          42000.0
# 2           3     VYBER   295021.8                    117          11253.0
# 3           4     VYBER   350971.4                    186           5553.0
# 4           5      None   166881.4                     84           5100.0
#
#    Min_transaction  AVG_transaction    TransactionMode  \
# 0             14.6      1569.767782  Withdrawl in cash
# 1             13.5      6593.052929  Other transaction
# 2             14.6      2521.553846  Withdrawl in cash
# 3             14.6      1886.943011  Withdrawl in cash
# 4              3.5      1986.683333  Other transaction
#
#   TransactionCharacterization  UsedForCredit  Withdrawl
# 0       Payment for statement            102        137
# 1            Intrest credited            152        305
# 2       Payment for statement             46         71
# 3       Payment for statement             65        121
# 4            Intrest credited             35         49

# %%
card_a = card

# %%
card_a = pysqldf("""
SELECT account_id, 
count(type) as number_of_cardtrypes
FROM card_a
GROUP BY account_id
""")

# %%
card_a.head()
# Out:
#    account_id  number_of_cardtrypes
# 0           9                     1
# 1          19                     1
# 2          41                     1
# 3          42                     1
# 4          51                     1

# %%
Table3 = pd.merge(Table3,order_a, how = 'left', on = 'account_id')
Table3 = pd.merge(Table3,trans_a, how = 'left', on = 'account_id')
#Table3 = pd.merge(Table3,card_a, how = 'left', on = 'account_id')

# %%
Table3
# Out:
#       client_id  birth_number  district_id_x  birth_year  age  birth_month  \
# 0             1        706213             18        1970   29           12
# 1             2        450204              1        1945   54            2
# 2             3        406009              1        1940   59           10
# 3             4        561201              5        1956   43           12
# 4             5        605703              5        1960   39            7
# 5             6        190922             12        1919   80            9
# 6             7        290125             15        1929   70            1
# 7             8        385221             51        1938   61            2
# 8             9        351016             60        1935   64           10
# 9            10        430501             57        1943   56            5
# 10           11        505822             57        1950   49            8
# 11           12        810220             40        1981   18            2
# 12           13        745529             54        1974   25            5
# 13           14        425622             76        1942   57            6
# 14           15        185828             21        1918   81            8
# 15           16        190225             21        1919   80            2
# 16           17        341013             76        1934   65           10
# 17           18        315405             76        1931   68            4
# 18           19        421228             47        1942   57           12
# 19           20        790104             46        1979   20            1
# 20           21        526029             12        1952   47           10
# 21           22        696011              1        1969   30           10
# 22           23        730529              1        1973   26            5
# 23           24        395729             43        1939   60            7
# 24           25        395423             21        1939   60            4
# 25           26        695420             74        1969   30            4
# 26           27        665326             54        1966   33            3
# 27           28        450929              1        1945   54            9
# 28           29        515911             30        1951   48            9
# 29           30        576009             74        1957   42           10
# ...         ...           ...            ...         ...  ...          ...
# 5339      13588        740129             46        1974   25            1
# 5340      13590        770803             59        1977   22            8
# 5341      13603        410728             46        1941   58            7
# 5342      13608        635515             37        1963   36            5
# 5343      13620        700726             16        1970   29            7
# 5344      13640        555609             28        1955   44            6
# 5345      13657        635512             59        1963   36            5
# 5346      13658        570423             59        1957   42            4
# 5347      13673        710220             39        1971   28            2
# 5348      13687        590523             75        1959   40            5
# 5349      13690        630516             70        1963   36            5
# 5350      13694        765120              1        1976   23            1
# 5351      13750        806113             12        1980   19           11
# 5352      13751        790720             12        1979   20            7
# 5353      13803        471114              1        1947   52           11
# 5354      13820        485731             33        1948   51            7
# 5355      13845        730216             15        1973   26            2
# 5356      13852        720126              5        1972   27            1
# 5357      13886        545412             44        1954   45            4
# 5358      13912        751120             50        1975   24           11
# 5359      13915        741123             77        1974   25           11
# 5360      13921        706220             62        1970   29           12
# 5361      13923        795222              7        1979   20            2
# 5362      13924        525909             54        1952   47            9
# 5363      13931        420101              8        1942   57            1
# 5364      13955        456030              1        1945   54           10
# 5365      13956        430406              1        1943   56            4
# 5366      13968        680413             61        1968   31            4
# 5367      13971        626019             67        1962   37           10
# 5368      13998        535812             74        1953   46            8
#
#       birth_day gender      district_name           region  ...  operation  \
# 0            13      F              Pisek    south Bohemia  ...      VYBER
# 1             4      M        Hl.m. Praha           Prague  ...       None
# 2             9      F        Hl.m. Praha           Prague  ...       None
# 3             1      M              Kolin  central Bohemia  ...      VYBER
# 4             3      F              Kolin  central Bohemia  ...      VYBER
# 5            22      M            Pribram  central Bohemia  ...      VYBER
# 6            25      M      Cesky Krumlov    south Bohemia  ...       None
# 7            21      F            Trutnov     east Bohemia  ...      VYBER
# 8            16      M          Prostejov    south Moravia  ...      VYBER
# 9             1      M            Hodonin    south Moravia  ...      VYBER
# 10           22      F            Hodonin    south Moravia  ...      VYBER
# 11           20      M            Teplice    north Bohemia  ...       None
# 12           29      F       Brno - mesto    south Moravia  ...       None
# 13           22      F            Sumperk    north Moravia  ...       None
# 14           28      F              Tabor    south Bohemia  ...      VYBER
# 15           25      M              Tabor    south Bohemia  ...      VYBER
# 16           13      M            Sumperk    north Moravia  ...      VYBER
# 17            5      F            Sumperk    north Moravia  ...      VYBER
# 18           28      M          Pardubice     east Bohemia  ...      VYBER
# 19            4      M             Nachod     east Bohemia  ...      VYBER
# 20           29      F            Pribram  central Bohemia  ...      VYBER
# 21           11      F        Hl.m. Praha           Prague  ...      VYBER
# 22           29      M        Hl.m. Praha           Prague  ...      VYBER
# 23           29      F     Hradec Kralove     east Bohemia  ...      VYBER
# 24           23      F              Tabor    south Bohemia  ...      VYBER
# 25           20      F    Ostrava - mesto    north Moravia  ...      VYBER
# 26           26      F       Brno - mesto    south Moravia  ...      VYBER
# 27           29      M        Hl.m. Praha           Prague  ...      VYBER
# 28           11      F            Sokolov     west Bohemia  ...      VYBER
# 29            9      F    Ostrava - mesto    north Moravia  ...      VYBER
# ...         ...    ...                ...              ...  ...        ...
# 5339         29      M             Nachod     east Bohemia  ...       None
# 5340          3      M           Kromeriz    south Moravia  ...      VYBER
# 5341         28      M             Nachod     east Bohemia  ...      VYBER
# 5342         15      F         Litomerice    north Bohemia  ...      VYBER
# 5343         26      M  Jindrichuv Hradec    south Bohemia  ...      VYBER
# 5344          9      F      Plzen - sever     west Bohemia  ...      VYBER
# 5345         12      F           Kromeriz    south Moravia  ...      VYBER
# 5346         23      M           Kromeriz    south Moravia  ...      VYBER
# 5347         20      M               Most    north Bohemia  ...       None
# 5348         23      M             Prerov    north Moravia  ...      VYBER
# 5349         16      M            Karvina    north Moravia  ...       None
# 5350         20      F        Hl.m. Praha           Prague  ...      VYBER
# 5351         13      F            Pribram  central Bohemia  ...      VYBER
# 5352         20      M            Pribram  central Bohemia  ...      VYBER
# 5353         14      M        Hl.m. Praha           Prague  ...      VYBER
# 5354         31      F              Decin    north Bohemia  ...      VYBER
# 5355         16      M      Cesky Krumlov    south Bohemia  ...      VYBER
# 5356         26      M              Kolin  central Bohemia  ...      VYBER
# 5357         12      F            Chrudim     east Bohemia  ...      VYBER
# 5358         20      M            Svitavy     east Bohemia  ...      VYBER
# 5359         23      M             Vsetin    north Moravia  ...      VYBER
# 5360         20      F   Uherske Hradiste    south Moravia  ...      VYBER
# 5361         22      F             Melnik  central Bohemia  ...      VYBER
# 5362          9      F       Brno - mesto    south Moravia  ...      VYBER
# 5363          1      M     Mlada Boleslav  central Bohemia  ...      VYBER
# 5364         30      F        Hl.m. Praha           Prague  ...      VYBER
# 5365          6      M        Hl.m. Praha           Prague  ...      VYBER
# 5366         13      M             Trebic    south Moravia  ...      VYBER
# 5367         19      F            Bruntal    north Moravia  ...      VYBER
# 5368         12      F    Ostrava - mesto    north Moravia  ...      VYBER
#
#        amount_y  number_of_transaction  Max_transaction  Min_transaction  \
# 0      375174.5                    239          12600.0             14.6
# 1     3151479.3                    478          42000.0             13.5
# 2     3151479.3                    478          42000.0             13.5
# 3      295021.8                    117          11253.0             14.6
# 4      295021.8                    117          11253.0             14.6
# 5      350971.4                    186           5553.0             14.6
# 6      166881.4                     84           5100.0              3.5
# 7      647567.1                    246          11600.0             14.6
# 8     1192039.9                    130          33975.0             14.6
# 9     1712906.1                    254          40800.0             14.6
# 10    1712906.1                    254          40800.0             14.6
# 11     696434.1                    361          45691.0              5.4
# 12    1040605.1                    156          26529.0             12.2
# 13     258100.1                    186           6700.0             10.2
# 14     216751.3                    106          11000.0             14.6
# 15     216751.3                    106          11000.0             14.6
# 16     208214.0                     75           7500.0             14.6
# 17     208214.0                     75           7500.0             14.6
# 18     785858.0                    124          22137.0             14.6
# 19    2329572.9                    365          46720.0             14.6
# 20     661403.9                     60          31262.0             14.6
# 21     413049.2                     54          49483.0             14.6
# 22     413049.2                     54          49483.0             14.6
# 23    3728698.3                    328          70200.0             30.0
# 24    1575515.9                    303          22708.0              0.9
# 25     154748.1                    116           4950.0             14.6
# 26     298432.3                     62          28000.0             14.6
# 27    2099466.5                    310          27600.0             14.6
# 28    3195860.0                    370          40480.0             14.6
# 29     688130.6                    140          26800.0             14.6
# ...         ...                    ...              ...              ...
# 5339  1804272.9                    131          63600.0             10.6
# 5340  1477648.7                    232          22780.0             30.0
# 5341  1773880.9                    403          18600.0             14.6
# 5342  2286264.8                    256          63100.0             14.6
# 5343  4041890.8                    246          73724.0             14.6
# 5344  1214997.1                    149          41280.0             14.6
# 5345  5552105.3                    492          60600.0             14.6
# 5346  5552105.3                    492          60600.0             14.6
# 5347  1043600.7                    146          47798.0              0.4
# 5348  2100479.6                    416          23204.0             14.6
# 5349  5371586.0                    325          64200.0             26.2
# 5350  1696208.3                    152          78600.0             30.0
# 5351  4222458.4                    339          58870.0             14.6
# 5352  4222458.4                    339          58870.0             14.6
# 5353  2185883.5                    173          66964.0             14.6
# 5354  2013634.6                    170          47600.0             14.6
# 5355  1284916.4                    484          17920.0             14.6
# 5356  1045427.8                    303          16833.0             14.6
# 5357  2880850.7                    563          47200.0              1.6
# 5358  2168077.9                    155          61700.0             14.6
# 5359  2518593.1                    364          33440.0              1.2
# 5360   978399.6                    149          49858.0              0.8
# 5361   559881.6                     75          30462.0             14.6
# 5362  1326820.0                    146          61000.0             14.6
# 5363  3295795.5                    368          62800.0              0.1
# 5364  3957372.2                    304          64800.0             30.0
# 5365  3957372.2                    304          64800.0             30.0
# 5366  2948081.4                    378          40521.0             14.6
# 5367  1330010.5                    344          24212.0             14.6
# 5368  2623161.9                    253          52800.0              0.5
#
#      AVG_transaction    TransactionMode  \
# 0        1569.767782  Withdrawl in cash
# 1        6593.052929  Other transaction
# 2        6593.052929  Other transaction
# 3        2521.553846  Withdrawl in cash
# 4        2521.553846  Withdrawl in cash
# 5        1886.943011  Withdrawl in cash
# 6        1986.683333  Other transaction
# 7        2632.386585  Withdrawl in cash
# 8        9169.537692  Withdrawl in cash
# 9        6743.724803  Withdrawl in cash
# 10       6743.724803  Withdrawl in cash
# 11       1929.180332  Other transaction
# 12       6670.545513  Other transaction
# 13       1387.634946  Other transaction
# 14       2044.823585  Withdrawl in cash
# 15       2044.823585  Withdrawl in cash
# 16       2776.186667  Withdrawl in cash
# 17       2776.186667  Withdrawl in cash
# 18       6337.564516  Withdrawl in cash
# 19       6382.391507  Withdrawl in cash
# 20      11023.398333  Withdrawl in cash
# 21       7649.059259  Withdrawl in cash
# 22       7649.059259  Withdrawl in cash
# 23      11367.982622  Withdrawl in cash
# 24       5199.722442  Withdrawl in cash
# 25       1334.035345  Withdrawl in cash
# 26       4813.424194  Withdrawl in cash
# 27       6772.472581  Withdrawl in cash
# 28       8637.459459  Withdrawl in cash
# 29       4915.218571  Withdrawl in cash
# ...              ...                ...
# 5339    13773.075573  Other transaction
# 5340     6369.175431  Withdrawl in cash
# 5341     4401.689578  Withdrawl in cash
# 5342     8930.721875  Withdrawl in cash
# 5343    16430.450407  Withdrawl in cash
# 5344     8154.342953  Withdrawl in cash
# 5345    11284.766870  Withdrawl in cash
# 5346    11284.766870  Withdrawl in cash
# 5347     7147.950000  Other transaction
# 5348     5049.229808  Withdrawl in cash
# 5349    16527.956923  Other transaction
# 5350    11159.265132  Withdrawl in cash
# 5351    12455.629499  Withdrawl in cash
# 5352    12455.629499  Withdrawl in cash
# 5353    12635.164740  Withdrawl in cash
# 5354    11844.909412  Withdrawl in cash
# 5355     2654.785950  Withdrawl in cash
# 5356     3450.256766  Withdrawl in cash
# 5357     5116.963943  Withdrawl in cash
# 5358    13987.599355  Withdrawl in cash
# 5359     6919.211813  Withdrawl in cash
# 5360     6566.440268  Withdrawl in cash
# 5361     7465.088000  Withdrawl in cash
# 5362     9087.808219  Withdrawl in cash
# 5363     8955.966033  Withdrawl in cash
# 5364    13017.671711  Withdrawl in cash
# 5365    13017.671711  Withdrawl in cash
# 5366     7799.157143  Withdrawl in cash
# 5367     3866.309593  Withdrawl in cash
# 5368    10368.228854  Withdrawl in cash
#
#                 TransactionCharacterization  UsedForCredit Withdrawl
# 0                     Payment for statement            102       137
# 1                          Intrest credited            152       305
# 2                          Intrest credited            152       305
# 3                     Payment for statement             46        71
# 4                     Payment for statement             46        71
# 5                     Payment for statement             65       121
# 6                          Intrest credited             35        49
# 7                     Payment for statement             99       147
# 8                     Payment for statement             51        79
# 9                     Payment for statement             84       170
# 10                    Payment for statement             84       170
# 11                         Intrest credited            183       178
# 12                         Intrest credited             59        97
# 13                         Intrest credited             79       107
# 14                    Payment for statement             39        67
# 15                    Payment for statement             39        67
# 16                    Payment for statement             31        44
# 17                    Payment for statement             31        44
# 18                    Payment for statement             52        72
# 19                    Payment for statement            129       236
# 20                    Payment for statement             32        28
# 21                    Payment for statement             33        19
# 22                    Payment for statement             33        19
# 23                    Payment for statement            156       132
# 24    Sanction interest if negative balance            152       148
# 25                    Payment for statement             53        63
# 26                    Payment for statement             34        28
# 27                    Payment for statement            118       192
# 28                    Payment for statement            137       233
# 29                    Payment for statement             52        88
# ...                                     ...            ...       ...
# 5339                       Intrest credited             70        57
# 5340                  Payment for statement            101       118
# 5341                  Payment for statement            140       263
# 5342                  Payment for statement             95       150
# 5343                  Payment for statement             85       147
# 5344                  Payment for statement             52        97
# 5345                  Payment for statement            189       288
# 5346                  Payment for statement            189       288
# 5347                       Intrest credited             73        58
# 5348                  Payment for statement            132       284
# 5349                       Intrest credited            131       184
# 5350                  Payment for statement             67        73
# 5351                  Payment for statement            106       224
# 5352                  Payment for statement            106       224
# 5353                  Payment for statement             48       108
# 5354                  Payment for statement             67        95
# 5355                  Payment for statement            168       316
# 5356                  Payment for statement             95       206
# 5357  Sanction interest if negative balance            225       338
# 5358                  Payment for statement             54        97
# 5359  Sanction interest if negative balance            199       165
# 5360  Sanction interest if negative balance             58        87
# 5361                  Payment for statement             30        45
# 5362                  Payment for statement             63        74
# 5363  Sanction interest if negative balance            183       156
# 5364                  Payment for statement             91       193
# 5365                  Payment for statement             91       193
# 5366                  Payment for statement            104       271
# 5367                  Payment for statement             81       263
# 5368  Sanction interest if negative balance            121       117
#
# [5369 rows x 45 columns]

# %%
Table3.to_csv(r'C:\Users\abannem\Downloads\group_project.csv')

# %%
 WithdrawlsAVG = pysqldf("""
 SELECT district_name, Withdrawl
 FROM Table3
 WHERE withdrawl > 450
 """)

# %%
WithdrawlsAVG.nunique()
# Out:
# district_name    12
# Withdrawl        10
# dtype: int64

# %%
cumsum = np.cumsum(Table3["Withdrawl"])
Districts = Table3["district_name"]
Withdrawls = Table3["Withdrawl"]
unique_districts = (Table3["district_name"]).nunique()
print(unique_districts)
# Out:
# 77

# %%
def top10 (x):
    unique_list = []
    
    for x in Table3[""]:
        if x > 150:
# Out:
#   File "<ipython-input-66-a4abfe060ece>", line 5
#     if x > 150:
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import gridplot

# %%
# Create a figure with a datetime type x-axis
fig = figure(title='Historical Bank Data',
             plot_height=400, plot_width=700,
             x_axis_label='District', y_axis_label='Withdarwl',
             x_minor_ticks=2, y_range=(0,1000),
             toolbar_location=None)

# The daily words will be represented as vertical bars (columns)
fig.vbar(x=Districts, bottom=0, top=Withdrawls, 
         color='blue', width=0.75, 
         legend='Withdrawls')

# The cumulative sum will be a trend line
fig.line(x=Districts, y = cumsum, 
         color='gray', line_width=1,
         legend='Cumulative')

# Put the legend in the upper left corner
fig.legend.location = 'top_left'

show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-635aa2a63424> in <module>
#       1 # Create a figure with a datetime type x-axis
# ----> 2 fig = figure(title='Historical Bank Data',
#       3              plot_height=400, plot_width=700,
#       4              x_axis_label='District', y_axis_label='Withdarwl',
#       5              x_minor_ticks=2, y_range=(0,1000),
#
# NameError: name 'figure' is not defined
